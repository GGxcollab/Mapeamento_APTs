# %%
import pandas as pd

df = pd.read_excel("Mapeamento de APTs - BBTS e BBA.xlsx", sheet_name='BBTS')
display(df)
# Out:
#           Finance Public Administration        Information
# 0       admin@338                 APT12              APT12
# 1           APT19                 APT18              APT17
# 2           APT38                 APT38              APT18
# 3           APT41         Aquatic Panda              APT19
# 4        Carbanak                 Axiom              APT41
# 5    Cobalt Group               Cleaver      Aquatic Panda
# 6      Deep Panda                CURIUM   Blue Mockingbird
# 7        Equation          Dark Caracal       Dark Caracal
# 8         Evilnum            Deep Panda         Deep Panda
# 9           FIN13             Dragonfly           DragonOK
# 10          GCMAN              DragonOK          Elderwood
# 11  Indrik Spider              Equation           Equation
# 12       menuPass         Indrik Spider        EXOTIC LILY
# 13         OilRig             Ke3change    GOLD SOUTHFIELD
# 14          Rocke         Lazarus Group      Indrik Spider
# ...
